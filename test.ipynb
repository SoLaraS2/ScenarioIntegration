# %%
import scenario_integration as si

# %%
integrator = si.ScenarioIntegrator()  

df1 = integrator.process(
    year=2030,
    scenario="baseline",
    custom_values={("texas","passenger car"): 1.1},
    fallback_scenarios={("texas","transit bus"): "central"},
    state_base_scenarios={"texas": "central"},
    shed_shift_enabled={"texas": True},
)

df2 = integrator.add_datacenter_capacity(
    year=2030, base_year=2030, adding_MW=100_000,
    cooling_prop_scenario="average", wy_scale_scenario="average",
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 integrator = si.ScenarioIntegrator()
# ----> 3 df1 = integrator.process(
#       4     year=2030,
#       5     scenario="baseline",
#       6     custom_values={("texas","passenger car"): 1.1},
#       7     fallback_scenarios={("texas","transit bus"): "central"},
#       8     state_base_scenarios={"texas": "central"},
#       9     shed_shift_enabled={"texas": True},
#      10 )
#      12 df2 = integrator.add_datacenter_capacity(
#      13     year=2030, base_year=2030, adding_MW=100_000,
#      14     cooling_prop_scenario="average", wy_scale_scenario="average",
#      15 )
#
# File ~\Desktop\tool_pkg\ScenarioIntegration\src\scenario_integration\core.py:45, in ScenarioIntegrator.process(self, year, scenario, custom_values, fallback_scenarios, state_base_scenarios, shed_shift_enabled, diagnostics)
# ...

# %%
si.ScenarioIntegrator().help
# Out:
# ScenarioIntegrator Help=========================================================
# Main methods:
#
# • process(year, scenario, *, ...)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 si.ScenarioIntegrator().help
#
# File ~\Desktop\tool_pkg\ScenarioIntegration\src\scenario_integration\core.py:54, in ScenarioIntegrator.help(self)
#      51 print("Main methods:\n")
#      53 print("• process(year, scenario, *, ...)")
# ---> 54 print(textwrap.dedent("""
#      55     - year: int
#      56     - scenario: str ("baseline" | "central" | "conservative")
#      57     - custom_values: dict[(state, subsector) -> float]
#      58           Example: {("texas","passenger car"): 1.10}
#      59     - fallback_scenarios: dict[(state, subsector) -> scenario]
#      60     - state_base_scenarios: dict[state -> scenario]
# ...
