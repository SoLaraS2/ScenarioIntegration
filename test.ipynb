# %%
import scenario_integration as si
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import scenario_integration as si
#
# ModuleNotFoundError: No module named 'scenario_integration'

# %%
pip install -e .
# Out:
# Obtaining file:///C:/Users/lbezerra/Desktop/tool_pkg/ScenarioIntegration
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Building editable for scenario-integration (pyproject.toml): started
#   Building editable for scenario-integration (pyproject.toml): finished with status 'done'
#   Created wheel for scenario-integration: filename=scenario_integration-0.1.0-0.editable-py3-none-any.whl size=1661 sha256=cbd9501bfd97b02cccaeb9955d535202cece195933c49c1f827b8e18aefb635e
# ...

# %%
import sys, pkgutil, pathlib
print("Kernel python:", sys.executable)
print("Has scenario_integration?", any(m.name=="scenario_integration" for m in pkgutil.iter_modules()))

# where would it import from?
import site, pprint; pprint.pp(site.getsitepackages()); print(site.getusersitepackages())

# show .pth entries (editable installs)
for p in map(pathlib.Path, site.getsitepackages()+[site.getusersitepackages()]):
    for f in p.glob("*.pth"):
        print("PTH:", f, "->", f.read_text()[:200])
# Out:
# Kernel python: c:\Users\lbezerra\AppData\Local\Programs\Python\Python312\python.exe
# Has scenario_integration? False
# ['c:\\Users\\lbezerra\\AppData\\Local\\Programs\\Python\\Python312',
#  'c:\\Users\\lbezerra\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages']
# C:\Users\lbezerra\AppData\Roaming\Python\Python312\site-packages
# PTH: c:\Users\lbezerra\AppData\Local\Programs\Python\Python312\Lib\site-packages\distutils-precedence.pth -> import os; var = 'SETUPTOOLS_USE_DISTUTILS'; enabled = os.environ.get(var, 'local') == 'local'; enabled and __import__('_distutils_hack').add_shim();
#
# PTH: c:\Users\lbezerra\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip_system_certs.pth -> import os, sys; __import__('pip_system_certs.bootstrap') and sys.modules['pip_system_certs.bootstrap'].bootstrap()
#
# ...
